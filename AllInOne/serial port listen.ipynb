# %%
import serial
import csv
import time

# Establish serial connection
ser = serial.Serial('COM7', 115200)  

# Open CSV file for writing
with open('sensor_data.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Timestamp', 'mq3', 'mq2', 'mq6', 'mq9', 'mq8', 'mq5', 'mics_Vnox', 'mics_Vred']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()

    # Read and write data indefinitely
    try:
        while True:
            # Read data from serial port
            line = ser.readline().decode('utf-8').strip()
            sensor_data = line.split()

            # Get current timestamp
            timestamp = time.strftime('%Y-%m-%d %H:%M:%S')

            # Write data to CSV file
            writer.writerow({'Timestamp': timestamp,
                             'mq3': sensor_data[0].replace(',', ''),   # Use correct keys
                             'mq2': sensor_data[1].replace(',', ''),  
                             'mq6': sensor_data[2].replace(',', ''),
                             'mq9': sensor_data[3].replace(',', ''),
                             'mq8': sensor_data[4].replace(',', ''),
                             'mq5': sensor_data[5].replace(',', ''),
                             'mics_Vnox': sensor_data[6].replace(',', ''),
                             'mics_Vred': sensor_data[7]
                            })
            csvfile.flush()  # Ensure data is written immediately

            # Print data to console
            print("Data written to CSV:", timestamp, sensor_data)

    except KeyboardInterrupt:
        print("Exiting...")
        ser.close()  # Close serial connection when exiting
# Out:
# Data written to CSV: 2024-04-02 11:28:06 ['35,', '0,', '2297,', '1861,', '603,', '0,', '689,', '0']
# Data written to CSV: 2024-04-02 11:28:07 ['2783,', '0,', '2297,', '1862,', '588,', '0,', '720,', '0']
# Data written to CSV: 2024-04-02 11:28:08 ['3665,', '0,', '2291,', '1860,', '599,', '0,', '763,', '0']
# Data written to CSV: 2024-04-02 11:28:09 ['864,', '0,', '2295,', '1866,', '591,', '0,', '730,', '0']
# Data written to CSV: 2024-04-02 11:28:10 ['0,', '0,', '2294,', '1859,', '589,', '0,', '687,', '0']
# Data written to CSV: 2024-04-02 11:28:11 ['3178,', '0,', '2290,', '1861,', '597,', '0,', '722,', '0']
# Data written to CSV: 2024-04-02 11:28:12 ['3157,', '0,', '2295,', '1863,', '612,', '0,', '761,', '0']
# Data written to CSV: 2024-04-02 11:28:13 ['0,', '0,', '2290,', '1862,', '609,', '0,', '704,', '0']
# Data written to CSV: 2024-04-02 11:28:14 ['1575,', '0,', '2291,', '1836,', '609,', '0,', '698,', '0']
# ...
