# %%
import serial
import csv
import time

# Establish serial connection
ser = serial.Serial('COM8', 115200)  

# Open CSV file for writing
with open('sensor_data.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Timestamp', 'mq2', 'mq3', 'mq5', 'mq6', 'mq8', 'mq9', 'mics_Vred', 'mics_Vnox','mq214']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()

    # Read and write data indefinitely
    try:
        while True:
            # Read data from serial port
            line = ser.readline().decode('utf-8').strip()
            sensor_data = line.split()

            # Get current timestamp
            timestamp = time.strftime('%Y-%m-%d %H:%M:%S')

            # Write data to CSV file
            writer.writerow({'Timestamp': timestamp,
                             'mq2': sensor_data[0].replace(',', ''), # Use correct keys
                             'mq3': sensor_data[1].replace(',', ''),  
                             'mq5': sensor_data[2].replace(',', ''),
                             'mq6': sensor_data[3].replace(',', ''),
                             'mq8': sensor_data[4].replace(',', ''),
                             'mq9': sensor_data[5].replace(',', ''),
                             'mics_Vred': sensor_data[6].replace(',', ''),
                             'mics_Vnox': sensor_data[7].replace(',', ''),
                             'mq214': sensor_data[8]
                            })
            csvfile.flush()  # Ensure data is written immediately

            # Print data to console
            print("Data written to CSV:", timestamp, sensor_data)

    except KeyboardInterrupt:
        print("Exiting...")
        ser.close()  # Close serial connection when exiting
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# <ipython-input-3-cebc81def531> in <module>
#       4
#       5 # Establish serial connection
# ----> 6 ser = serial.Serial('COM8', 115200)
#       7
#       8 # Open CSV file for writing
#
# ~\AppData\Roaming\Python\Python36\site-packages\serial\serialwin32.py in __init__(self, *args, **kwargs)
#      31         self._overlapped_read = None
#      32         self._overlapped_write = None
# ---> 33         super(Serial, self).__init__(*args, **kwargs)
#      34
#      35     def open(self):
#
# ~\AppData\Roaming\Python\Python36\site-packages\serial\serialutil.py in __init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     242
#     243         if port is not None:
# --> 244             self.open()
#     245
#     246     #  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#
# ~\AppData\Roaming\Python\Python36\site-packages\serial\serialwin32.py in open(self)
#      62         if self._port_handle == win32.INVALID_HANDLE_VALUE:
#      63             self._port_handle = None    # 'cause __del__ is called anyway
# ---> 64             raise SerialException("could not open port {!r}: {!r}".format(self.portstr, ctypes.WinError()))
#      65
#      66         try:
#
# SerialException: could not open port 'COM8': PermissionError(13, 'Access is denied.', None, 5)

# %%
import serial
import csv
import time

# Establish serial connection
ser = serial.Serial('COM8', 115200)  

# Open CSV file for writing
with open('sensor_data.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Timestamp', 'mq2', 'mq3', 'mq5', 'mq6', 'mq8', 'mq9', 'mics_Vred', 'mics_Vnox','mq214']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()

    # Read and write data indefinitely
    try:
        while True:
            # Read data from serial port
            line = ser.readline().decode('utf-8').strip()
            sensor_data = line.split()

            # Get current timestamp
            timestamp = time.strftime('%Y-%m-%d %H:%M:%S')

            # Write data to CSV file
            writer.writerow({'Timestamp': timestamp,
                             'mq2': sensor_data[0].replace(',', ''), # Use correct keys
                             'mq3': sensor_data[1].replace(',', ''),  
                             'mq5': sensor_data[2].replace(',', ''),
                             'mq6': sensor_data[3].replace(',', ''),
                             'mq8': sensor_data[4].replace(',', ''),
                             'mq9': sensor_data[5].replace(',', ''),
                             'mics_Vred': sensor_data[6].replace(',', ''),
                             'mics_Vnox': sensor_data[7].replace(',', ''),
                             'mq214': sensor_data[8]
                            })
            csvfile.flush()  # Ensure data is written immediately

            # Print data to console
            print("Data written to CSV:", timestamp, sensor_data)

    except KeyboardInterrupt:
        print("Exiting...")
        ser.close()  # Close serial connection when exiting
# Out:
# Data written to CSV: 2024-04-29 10:54:35 ['484,', '243,', '244,', '683,', '220,', '541,', '127,', '808,', '904']
# Data written to CSV: 2024-04-29 10:54:36 ['484,', '241,', '242,', '682,', '217,', '540,', '126,', '637,', '903']
# Data written to CSV: 2024-04-29 10:54:37 ['483,', '241,', '242,', '682,', '217,', '540,', '127,', '631,', '903']
# Data written to CSV: 2024-04-29 10:54:38 ['484,', '241,', '242,', '682,', '218,', '540,', '128,', '627,', '903']
# Data written to CSV: 2024-04-29 10:54:39 ['485,', '242,', '243,', '683,', '219,', '541,', '129,', '624,', '903']
# Data written to CSV: 2024-04-29 10:54:40 ['484,', '242,', '243,', '683,', '219,', '541,', '129,', '621,', '903']
# Data written to CSV: 2024-04-29 10:54:41 ['485,', '244,', '244,', '683,', '220,', '542,', '130,', '618,', '903']
# Data written to CSV: 2024-04-29 10:54:42 ['485,', '243,', '243,', '683,', '220,', '541,', '129,', '616,', '903']
# Data written to CSV: 2024-04-29 10:54:43 ['485,', '244,', '243,', '683,', '220,', '541,', '129,', '614,', '903']
# Data written to CSV: 2024-04-29 10:54:44 ['485,', '244,', '243,', '683,', '220,', '541,', '129,', '613,', '903']
# Data written to CSV: 2024-04-29 10:54:45 ['485,', '244,', '243,', '683,', '221,', '542,', '129,', '610,', '903']
# Data written to CSV: 2024-04-29 10:54:46 ['484,', '244,', '243,', '683,', '220,', '541,', '128,', '610,', '903']
# Data written to CSV: 2024-04-29 10:54:47 ['484,', '244,', '242,', '683,', '220,', '541,', '128,', '608,', '903']
# Data written to CSV: 2024-04-29 10:54:48 ['484,', '245,', '243,', '683,', '221,', '542,', '129,', '606,', '903']
# Data written to CSV: 2024-04-29 10:54:49 ['484,', '245,', '243,', '682,', '221,', '542,', '128,', '605,', '903']
# Data written to CSV: 2024-04-29 10:54:50 ['484,', '245,', '243,', '683,', '221,', '542,', '128,', '604,', '903']
# Data written to CSV: 2024-04-29 10:54:51 ['483,', '244,', '242,', '682,', '220,', '542,', '128,', '603,', '903']
# Data written to CSV: 2024-04-29 10:54:52 ['484,', '246,', '244,', '683,', '222,', '543,', '129,', '601,', '903']
# Data written to CSV: 2024-04-29 10:54:53 ['482,', '243,', '241,', '681,', '219,', '541,', '126,', '601,', '903']
# Data written to CSV: 2024-04-29 10:54:54 ['482,', '244,', '241,', '681,', '219,', '541,', '126,', '600,', '903']
# Data written to CSV: 2024-04-29 10:54:55 ['481,', '243,', '240,', '681,', '218,', '540,', '125,', '599,', '902']
# Data written to CSV: 2024-04-29 10:54:56 ['480,', '242,', '239,', '680,', '218,', '540,', '125,', '599,', '902']
# Data written to CSV: 2024-04-29 10:54:57 ['481,', '243,', '239,', '680,', '218,', '540,', '125,', '597,', '902']
# Data written to CSV: 2024-04-29 10:54:58 ['480,', '242,', '238,', '680,', '217,', '539,', '124,', '597,', '902']
# Data written to CSV: 2024-04-29 10:54:59 ['479,', '242,', '238,', '680,', '217,', '539,', '124,', '596,', '902']
# Data written to CSV: 2024-04-29 10:55:00 ['479,', '242,', '238,', '680,', '217,', '539,', '124,', '595,', '902']
# Data written to CSV: 2024-04-29 10:55:01 ['479,', '242,', '238,', '679,', '217,', '539,', '123,', '594,', '902']
# Data written to CSV: 2024-04-29 10:55:02 ['479,', '243,', '238,', '680,', '218,', '540,', '124,', '593,', '902']
# Data written to CSV: 2024-04-29 10:55:03 ['479,', '243,', '238,', '680,', '217,', '539,', '124,', '593,', '902']
# Data written to CSV: 2024-04-29 10:55:04 ['479,', '242,', '238,', '679,', '217,', '539,', '123,', '591,', '902']
# Data written to CSV: 2024-04-29 10:55:05 ['478,', '242,', '237,', '679,', '216,', '539,', '122,', '591,', '902']
# Data written to CSV: 2024-04-29 10:55:06 ['478,', '241,', '237,', '679,', '216,', '539,', '122,', '590,', '902']
# Data written to CSV: 2024-04-29 10:55:07 ['475,', '237,', '232,', '677,', '212,', '536,', '118,', '590,', '901']
# Data written to CSV: 2024-04-29 10:55:08 ['475,', '237,', '232,', '677,', '212,', '536,', '118,', '589,', '901']
# Data written to CSV: 2024-04-29 10:55:09 ['475,', '238,', '232,', '677,', '212,', '536,', '118,', '588,', '901']
# Data written to CSV: 2024-04-29 10:55:10 ['476,', '240,', '234,', '677,', '214,', '537,', '120,', '588,', '901']
# Data written to CSV: 2024-04-29 10:55:11 ['474,', '237,', '231,', '676,', '211,', '536,', '118,', '587,', '901']
# Data written to CSV: 2024-04-29 10:55:12 ['474,', '238,', '232,', '676,', '212,', '536,', '118,', '586,', '901']
# Data written to CSV: 2024-04-29 10:55:13 ['474,', '238,', '232,', '677,', '212,', '536,', '118,', '585,', '901']
# Data written to CSV: 2024-04-29 10:55:14 ['487,', '257,', '251,', '684,', '232,', '548,', '136,', '582,', '903']
# Data written to CSV: 2024-04-29 10:55:15 ['484,', '254,', '248,', '682,', '229,', '546,', '133,', '584,', '903']
# Data written to CSV: 2024-04-29 10:55:17 ['482,', '252,', '246,', '681,', '227,', '544,', '130,', '582,', '903']
# Data written to CSV: 2024-04-29 10:55:18 ['482,', '252,', '246,', '681,', '227,', '545,', '131,', '583,', '903']
# Data written to CSV: 2024-04-29 10:55:19 ['479,', '250,', '244,', '680,', '224,', '543,', '128,', '582,', '902']
# Data written to CSV: 2024-04-29 10:55:20 ['479,', '250,', '244,', '679,', '224,', '542,', '129,', '583,', '903']
# Data written to CSV: 2024-04-29 10:55:21 ['478,', '249,', '242,', '679,', '223,', '542,', '128,', '582,', '903']
# Data written to CSV: 2024-04-29 10:55:22 ['478,', '249,', '242,', '678,', '223,', '541,', '128,', '582,', '902']
# Data written to CSV: 2024-04-29 10:55:23 ['478,', '250,', '243,', '679,', '223,', '541,', '128,', '580,', '903']
# Data written to CSV: 2024-04-29 10:55:24 ['477,', '249,', '242,', '678,', '223,', '541,', '128,', '580,', '903']
# Data written to CSV: 2024-04-29 10:55:25 ['476,', '248,', '241,', '678,', '221,', '540,', '126,', '580,', '902']
# Data written to CSV: 2024-04-29 10:55:26 ['476,', '247,', '240,', '677,', '221,', '539,', '126,', '580,', '902']
# Data written to CSV: 2024-04-29 10:55:27 ['476,', '248,', '240,', '677,', '221,', '540,', '127,', '580,', '902']
# Data written to CSV: 2024-04-29 10:55:28 ['475,', '247,', '239,', '677,', '220,', '539,', '125,', '579,', '902']
# Data written to CSV: 2024-04-29 10:55:29 ['475,', '247,', '239,', '677,', '220,', '539,', '126,', '578,', '902']
# Data written to CSV: 2024-04-29 10:55:30 ['475,', '247,', '239,', '677,', '221,', '539,', '126,', '578,', '902']
# Data written to CSV: 2024-04-29 10:55:31 ['475,', '247,', '238,', '676,', '220,', '539,', '125,', '578,', '902']
# Data written to CSV: 2024-04-29 10:55:32 ['475,', '246,', '238,', '676,', '219,', '538,', '125,', '578,', '902']
# Data written to CSV: 2024-04-29 10:55:33 ['475,', '247,', '239,', '676,', '221,', '539,', '126,', '576,', '902']
# Data written to CSV: 2024-04-29 10:55:34 ['475,', '247,', '238,', '676,', '220,', '539,', '126,', '577,', '902']
# Data written to CSV: 2024-04-29 10:55:35 ['474,', '247,', '238,', '676,', '220,', '538,', '125,', '577,', '902']
# Data written to CSV: 2024-04-29 10:55:36 ['474,', '247,', '238,', '676,', '220,', '538,', '126,', '578,', '902']
# Data written to CSV: 2024-04-29 10:55:37 ['473,', '246,', '237,', '675,', '219,', '538,', '125,', '577,', '902']
# Data written to CSV: 2024-04-29 10:55:38 ['473,', '246,', '237,', '675,', '219,', '538,', '124,', '576,', '902']
# Data written to CSV: 2024-04-29 10:55:39 ['473,', '246,', '237,', '675,', '219,', '538,', '124,', '575,', '902']
# Data written to CSV: 2024-04-29 10:55:40 ['473,', '246,', '236,', '675,', '219,', '538,', '124,', '575,', '902']
# Data written to CSV: 2024-04-29 10:55:41 ['473,', '245,', '236,', '675,', '218,', '538,', '124,', '575,', '901']
# Data written to CSV: 2024-04-29 10:55:42 ['473,', '245,', '236,', '675,', '219,', '537,', '124,', '575,', '902']
# Data written to CSV: 2024-04-29 10:55:43 ['472,', '245,', '235,', '674,', '218,', '537,', '124,', '575,', '901']
# Data written to CSV: 2024-04-29 10:55:44 ['473,', '245,', '235,', '675,', '219,', '538,', '125,', '574,', '902']
# Data written to CSV: 2024-04-29 10:55:45 ['472,', '245,', '235,', '675,', '218,', '537,', '124,', '575,', '901']
# Data written to CSV: 2024-04-29 10:55:46 ['471,', '244,', '234,', '674,', '217,', '537,', '123,', '574,', '901']
# Data written to CSV: 2024-04-29 10:55:47 ['471,', '244,', '233,', '674,', '216,', '536,', '122,', '574,', '901']
# Data written to CSV: 2024-04-29 10:55:48 ['471,', '244,', '233,', '673,', '216,', '536,', '122,', '574,', '901']
# Data written to CSV: 2024-04-29 10:55:49 ['470,', '243,', '232,', '673,', '216,', '536,', '122,', '573,', '901']
# Data written to CSV: 2024-04-29 10:55:50 ['470,', '243,', '232,', '673,', '216,', '536,', '122,', '573,', '901']
# Data written to CSV: 2024-04-29 10:55:51 ['470,', '243,', '232,', '673,', '216,', '535,', '122,', '573,', '901']
# Data written to CSV: 2024-04-29 10:55:52 ['470,', '244,', '232,', '674,', '217,', '537,', '122,', '573,', '901']
# Data written to CSV: 2024-04-29 10:55:53 ['471,', '245,', '234,', '674,', '218,', '537,', '123,', '572,', '901']
# Data written to CSV: 2024-04-29 10:55:54 ['470,', '244,', '232,', '673,', '217,', '536,', '122,', '572,', '901']
# Data written to CSV: 2024-04-29 10:55:55 ['469,', '243,', '231,', '673,', '215,', '535,', '121,', '572,', '901']
# Data written to CSV: 2024-04-29 10:55:56 ['469,', '243,', '231,', '673,', '215,', '535,', '121,', '572,', '901']
# Data written to CSV: 2024-04-29 10:55:57 ['469,', '242,', '230,', '672,', '215,', '535,', '121,', '571,', '900']
# Data written to CSV: 2024-04-29 10:55:58 ['469,', '242,', '229,', '672,', '214,', '535,', '120,', '571,', '900']
# Data written to CSV: 2024-04-29 10:55:59 ['468,', '242,', '229,', '673,', '214,', '535,', '120,', '571,', '901']
# Data written to CSV: 2024-04-29 10:56:00 ['468,', '242,', '229,', '672,', '215,', '535,', '120,', '572,', '900']
# Data written to CSV: 2024-04-29 10:56:01 ['468,', '241,', '229,', '672,', '214,', '534,', '119,', '571,', '900']
# Data written to CSV: 2024-04-29 10:56:02 ['468,', '241,', '229,', '672,', '214,', '534,', '119,', '570,', '900']
# Data written to CSV: 2024-04-29 10:56:03 ['468,', '241,', '228,', '672,', '214,', '535,', '119,', '569,', '900']
# Data written to CSV: 2024-04-29 10:56:04 ['467,', '242,', '228,', '672,', '214,', '535,', '120,', '569,', '900']
# Data written to CSV: 2024-04-29 10:56:05 ['468,', '242,', '228,', '672,', '214,', '535,', '119,', '569,', '900']
# Data written to CSV: 2024-04-29 10:56:06 ['467,', '242,', '229,', '672,', '214,', '535,', '119,', '568,', '900']
# Data written to CSV: 2024-04-29 10:56:07 ['468,', '242,', '229,', '672,', '215,', '535,', '120,', '568,', '900']
# Data written to CSV: 2024-04-29 10:56:08 ['468,', '243,', '229,', '672,', '215,', '535,', '121,', '569,', '900']
# Data written to CSV: 2024-04-29 10:56:09 ['469,', '244,', '231,', '673,', '217,', '536,', '122,', '568,', '901']
# Data written to CSV: 2024-04-29 10:56:10 ['468,', '243,', '229,', '672,', '216,', '536,', '121,', '567,', '900']
# Data written to CSV: 2024-04-29 10:56:11 ['468,', '244,', '230,', '672,', '216,', '536,', '122,', '568,', '900']
# Data written to CSV: 2024-04-29 10:56:12 ['468,', '243,', '229,', '672,', '216,', '535,', '121,', '568,', '901']
# Data written to CSV: 2024-04-29 10:56:13 ['467,', '243,', '229,', '671,', '216,', '535,', '121,', '567,', '900']
# Data written to CSV: 2024-04-29 10:56:14 ['467,', '243,', '229,', '671,', '215,', '535,', '121,', '567,', '900']
# Data written to CSV: 2024-04-29 10:56:15 ['466,', '243,', '228,', '671,', '215,', '535,', '120,', '566,', '900']
# Data written to CSV: 2024-04-29 10:56:16 ['466,', '243,', '228,', '671,', '215,', '535,', '120,', '566,', '900']
# Data written to CSV: 2024-04-29 10:56:17 ['467,', '243,', '228,', '671,', '215,', '535,', '120,', '566,', '900']
# Data written to CSV: 2024-04-29 10:56:18 ['466,', '243,', '228,', '671,', '215,', '535,', '120,', '566,', '900']
# Data written to CSV: 2024-04-29 10:56:19 ['466,', '242,', '227,', '671,', '214,', '535,', '120,', '565,', '900']
# Data written to CSV: 2024-04-29 10:56:20 ['466,', '242,', '227,', '670,', '214,', '534,', '120,', '564,', '900']
# Data written to CSV: 2024-04-29 10:56:21 ['465,', '242,', '227,', '670,', '214,', '534,', '120,', '564,', '900']
# Data written to CSV: 2024-04-29 10:56:22 ['466,', '243,', '227,', '670,', '215,', '535,', '120,', '564,', '900']
# Data written to CSV: 2024-04-29 10:56:23 ['465,', '242,', '227,', '670,', '214,', '534,', '120,', '564,', '900']
# Data written to CSV: 2024-04-29 10:56:24 ['465,', '242,', '227,', '670,', '215,', '534,', '120,', '564,', '900']
# Data written to CSV: 2024-04-29 10:56:25 ['465,', '242,', '226,', '670,', '214,', '534,', '119,', '563,', '900']
# Data written to CSV: 2024-04-29 10:56:26 ['465,', '242,', '226,', '669,', '214,', '534,', '119,', '564,', '900']
# Data written to CSV: 2024-04-29 10:56:27 ['464,', '242,', '226,', '670,', '214,', '534,', '119,', '563,', '900']
# Data written to CSV: 2024-04-29 10:56:28 ['464,', '242,', '226,', '669,', '214,', '534,', '119,', '563,', '900']
# Data written to CSV: 2024-04-29 10:56:29 ['464,', '242,', '226,', '669,', '214,', '534,', '119,', '562,', '900']
# Data written to CSV: 2024-04-29 10:56:30 ['464,', '242,', '225,', '669,', '214,', '534,', '119,', '562,', '900']
# Data written to CSV: 2024-04-29 10:56:31 ['464,', '242,', '226,', '669,', '214,', '534,', '120,', '562,', '900']
# Data written to CSV: 2024-04-29 10:56:32 ['464,', '242,', '225,', '669,', '214,', '534,', '120,', '561,', '900']
# Data written to CSV: 2024-04-29 10:56:33 ['463,', '242,', '225,', '669,', '214,', '533,', '119,', '561,', '900']
# Data written to CSV: 2024-04-29 10:56:34 ['464,', '242,', '225,', '669,', '214,', '533,', '120,', '561,', '900']
# Data written to CSV: 2024-04-29 10:56:35 ['463,', '242,', '225,', '669,', '214,', '533,', '119,', '561,', '900']
# Data written to CSV: 2024-04-29 10:56:36 ['463,', '243,', '225,', '669,', '215,', '534,', '120,', '560,', '900']
# Data written to CSV: 2024-04-29 10:56:37 ['463,', '243,', '225,', '668,', '214,', '534,', '120,', '560,', '900']
# Data written to CSV: 2024-04-29 10:56:39 ['463,', '242,', '225,', '668,', '214,', '533,', '120,', '560,', '900']
# Data written to CSV: 2024-04-29 10:56:40 ['463,', '242,', '225,', '668,', '214,', '533,', '120,', '560,', '900']
# Data written to CSV: 2024-04-29 10:56:41 ['463,', '242,', '225,', '668,', '214,', '533,', '120,', '560,', '900']
# Data written to CSV: 2024-04-29 10:56:42 ['463,', '242,', '225,', '668,', '214,', '533,', '120,', '560,', '900']
# Data written to CSV: 2024-04-29 10:56:43 ['462,', '242,', '224,', '668,', '214,', '533,', '119,', '561,', '900']
# Data written to CSV: 2024-04-29 10:56:44 ['462,', '242,', '224,', '668,', '214,', '533,', '120,', '560,', '899']
# Data written to CSV: 2024-04-29 10:56:45 ['462,', '242,', '223,', '667,', '213,', '533,', '119,', '560,', '899']
# Data written to CSV: 2024-04-29 10:56:46 ['462,', '242,', '223,', '667,', '213,', '533,', '120,', '562,', '899']
# Data written to CSV: 2024-04-29 10:56:47 ['462,', '242,', '223,', '668,', '213,', '533,', '120,', '562,', '900']
# Data written to CSV: 2024-04-29 10:56:48 ['462,', '242,', '223,', '668,', '214,', '533,', '120,', '562,', '899']
# Data written to CSV: 2024-04-29 10:56:49 ['462,', '242,', '223,', '668,', '214,', '533,', '120,', '561,', '900']
# Data written to CSV: 2024-04-29 10:56:50 ['463,', '242,', '223,', '668,', '214,', '533,', '120,', '561,', '899']
# Data written to CSV: 2024-04-29 10:56:51 ['462,', '243,', '223,', '668,', '214,', '533,', '120,', '561,', '899']
# Data written to CSV: 2024-04-29 10:56:52 ['463,', '244,', '225,', '669,', '216,', '534,', '122,', '560,', '900']
# Data written to CSV: 2024-04-29 10:56:53 ['462,', '242,', '223,', '668,', '214,', '533,', '120,', '560,', '899']
# Data written to CSV: 2024-04-29 10:56:54 ['462,', '242,', '223,', '667,', '214,', '533,', '120,', '560,', '899']
# Data written to CSV: 2024-04-29 10:56:55 ['462,', '243,', '223,', '667,', '214,', '533,', '120,', '560,', '899']
# Data written to CSV: 2024-04-29 10:56:56 ['462,', '243,', '223,', '667,', '214,', '533,', '120,', '559,', '899']
# Data written to CSV: 2024-04-29 10:56:57 ['462,', '243,', '222,', '667,', '214,', '533,', '120,', '559,', '899']
# Data written to CSV: 2024-04-29 10:56:58 ['461,', '243,', '222,', '667,', '214,', '533,', '120,', '559,', '899']
# Data written to CSV: 2024-04-29 10:56:59 ['461,', '243,', '222,', '667,', '214,', '533,', '120,', '559,', '899']
# Data written to CSV: 2024-04-29 10:57:00 ['461,', '243,', '222,', '667,', '213,', '533,', '120,', '559,', '899']
# Data written to CSV: 2024-04-29 10:57:01 ['461,', '242,', '222,', '667,', '214,', '533,', '120,', '558,', '899']
# Data written to CSV: 2024-04-29 10:57:02 ['461,', '243,', '222,', '667,', '214,', '533,', '120,', '558,', '899']
# Data written to CSV: 2024-04-29 10:57:03 ['460,', '242,', '222,', '666,', '213,', '533,', '120,', '558,', '899']
# Data written to CSV: 2024-04-29 10:57:04 ['460,', '242,', '221,', '666,', '213,', '532,', '119,', '558,', '899']
# Data written to CSV: 2024-04-29 10:57:05 ['460,', '242,', '221,', '666,', '213,', '533,', '119,', '557,', '899']
# Data written to CSV: 2024-04-29 10:57:06 ['460,', '243,', '221,', '666,', '213,', '533,', '120,', '557,', '899']
# Data written to CSV: 2024-04-29 10:57:07 ['460,', '243,', '221,', '666,', '213,', '533,', '120,', '557,', '899']
# Data written to CSV: 2024-04-29 10:57:08 ['460,', '243,', '221,', '666,', '213,', '533,', '120,', '556,', '899']
# Data written to CSV: 2024-04-29 10:57:09 ['460,', '243,', '221,', '666,', '213,', '533,', '120,', '556,', '898']
# Data written to CSV: 2024-04-29 10:57:10 ['459,', '242,', '220,', '666,', '213,', '532,', '119,', '556,', '899']
# Data written to CSV: 2024-04-29 10:57:11 ['459,', '242,', '220,', '665,', '212,', '532,', '119,', '556,', '899']
# Data written to CSV: 2024-04-29 10:57:12 ['459,', '242,', '220,', '665,', '212,', '532,', '119,', '555,', '899']
# Data written to CSV: 2024-04-29 10:57:13 ['459,', '242,', '220,', '665,', '212,', '532,', '119,', '556,', '899']
# Data written to CSV: 2024-04-29 10:57:14 ['459,', '242,', '220,', '665,', '212,', '532,', '119,', '554,', '899']
# Data written to CSV: 2024-04-29 10:57:15 ['459,', '242,', '220,', '665,', '213,', '532,', '119,', '555,', '899']
# Data written to CSV: 2024-04-29 10:57:16 ['458,', '241,', '219,', '665,', '212,', '531,', '119,', '554,', '899']
# Data written to CSV: 2024-04-29 10:57:17 ['458,', '242,', '219,', '665,', '212,', '531,', '119,', '554,', '899']
# Data written to CSV: 2024-04-29 10:57:18 ['458,', '242,', '219,', '665,', '213,', '532,', '119,', '554,', '899']
# Data written to CSV: 2024-04-29 10:57:19 ['458,', '242,', '219,', '665,', '212,', '531,', '119,', '554,', '898']
# Data written to CSV: 2024-04-29 10:57:20 ['458,', '242,', '219,', '665,', '212,', '531,', '119,', '553,', '899']
# Data written to CSV: 2024-04-29 10:57:21 ['458,', '241,', '218,', '664,', '212,', '531,', '118,', '553,', '898']
# Data written to CSV: 2024-04-29 10:57:22 ['457,', '241,', '218,', '664,', '212,', '531,', '118,', '552,', '899']
# Data written to CSV: 2024-04-29 10:57:23 ['457,', '241,', '218,', '664,', '211,', '531,', '118,', '553,', '898']
# Data written to CSV: 2024-04-29 10:57:24 ['457,', '241,', '218,', '664,', '211,', '531,', '118,', '552,', '898']
# Data written to CSV: 2024-04-29 10:57:25 ['457,', '241,', '218,', '664,', '211,', '531,', '118,', '552,', '898']
# Data written to CSV: 2024-04-29 10:57:26 ['457,', '241,', '218,', '664,', '212,', '531,', '118,', '552,', '898']
# Data written to CSV: 2024-04-29 10:57:27 ['457,', '241,', '218,', '664,', '212,', '531,', '118,', '551,', '898']
# Data written to CSV: 2024-04-29 10:57:28 ['457,', '241,', '218,', '664,', '212,', '531,', '118,', '551,', '898']
# Data written to CSV: 2024-04-29 10:57:29 ['457,', '241,', '218,', '664,', '212,', '531,', '118,', '551,', '898']
# Data written to CSV: 2024-04-29 10:57:30 ['457,', '241,', '218,', '664,', '212,', '531,', '118,', '551,', '898']
# Data written to CSV: 2024-04-29 10:57:31 ['457,', '242,', '218,', '664,', '212,', '531,', '119,', '551,', '898']
# Data written to CSV: 2024-04-29 10:57:32 ['456,', '241,', '218,', '663,', '212,', '531,', '118,', '550,', '899']
# Data written to CSV: 2024-04-29 10:57:33 ['456,', '242,', '218,', '664,', '212,', '531,', '119,', '550,', '898']
# Data written to CSV: 2024-04-29 10:57:34 ['456,', '241,', '217,', '663,', '212,', '530,', '118,', '550,', '898']
# Data written to CSV: 2024-04-29 10:57:35 ['456,', '241,', '217,', '663,', '212,', '530,', '118,', '550,', '898']
# Data written to CSV: 2024-04-29 10:57:36 ['456,', '242,', '217,', '663,', '212,', '530,', '119,', '549,', '898']
# Data written to CSV: 2024-04-29 10:57:37 ['456,', '242,', '218,', '663,', '212,', '531,', '119,', '549,', '898']
# Data written to CSV: 2024-04-29 10:57:38 ['456,', '242,', '217,', '663,', '212,', '530,', '119,', '549,', '898']
# Data written to CSV: 2024-04-29 10:57:39 ['456,', '241,', '217,', '663,', '212,', '530,', '118,', '548,', '899']
# Data written to CSV: 2024-04-29 10:57:40 ['456,', '242,', '217,', '663,', '212,', '530,', '119,', '549,', '898']
# Data written to CSV: 2024-04-29 10:57:41 ['455,', '241,', '216,', '662,', '211,', '530,', '118,', '548,', '898']
# Data written to CSV: 2024-04-29 10:57:42 ['454,', '240,', '215,', '662,', '210,', '529,', '117,', '548,', '898']
# Data written to CSV: 2024-04-29 10:57:43 ['454,', '240,', '215,', '662,', '210,', '529,', '117,', '547,', '898']
# Data written to CSV: 2024-04-29 10:57:44 ['454,', '240,', '215,', '662,', '210,', '529,', '117,', '548,', '898']
# Data written to CSV: 2024-04-29 10:57:45 ['454,', '240,', '215,', '662,', '210,', '529,', '117,', '548,', '898']
# Data written to CSV: 2024-04-29 10:57:46 ['454,', '240,', '214,', '661,', '210,', '529,', '117,', '547,', '898']
# Data written to CSV: 2024-04-29 10:57:47 ['454,', '240,', '214,', '661,', '209,', '529,', '116,', '547,', '898']
# Data written to CSV: 2024-04-29 10:57:48 ['454,', '240,', '214,', '661,', '210,', '529,', '117,', '547,', '898']
# Data written to CSV: 2024-04-29 10:57:49 ['453,', '240,', '214,', '661,', '210,', '529,', '117,', '547,', '898']
# Data written to CSV: 2024-04-29 10:57:50 ['453,', '240,', '214,', '661,', '210,', '529,', '116,', '547,', '898']
# Data written to CSV: 2024-04-29 10:57:51 ['453,', '240,', '214,', '661,', '210,', '529,', '117,', '546,', '898']
# Data written to CSV: 2024-04-29 10:57:52 ['454,', '241,', '215,', '661,', '211,', '529,', '118,', '546,', '898']
# Data written to CSV: 2024-04-29 10:57:53 ['454,', '241,', '215,', '662,', '211,', '529,', '118,', '546,', '898']
# Data written to CSV: 2024-04-29 10:57:54 ['454,', '242,', '216,', '662,', '212,', '530,', '119,', '546,', '898']
# Data written to CSV: 2024-04-29 10:57:55 ['455,', '243,', '217,', '662,', '213,', '531,', '120,', '544,', '898']
# Data written to CSV: 2024-04-29 10:57:56 ['453,', '241,', '215,', '661,', '211,', '529,', '118,', '545,', '898']
# Data written to CSV: 2024-04-29 10:57:57 ['454,', '243,', '217,', '662,', '213,', '530,', '120,', '544,', '898']
# Data written to CSV: 2024-04-29 10:57:58 ['454,', '242,', '216,', '661,', '212,', '530,', '119,', '545,', '898']
# Data written to CSV: 2024-04-29 10:57:59 ['453,', '242,', '215,', '661,', '212,', '529,', '118,', '545,', '898']
# Data written to CSV: 2024-04-29 10:58:00 ['453,', '241,', '215,', '661,', '211,', '529,', '118,', '545,', '898']
# Data written to CSV: 2024-04-29 10:58:02 ['452,', '241,', '214,', '660,', '210,', '528,', '118,', '545,', '898']
# Data written to CSV: 2024-04-29 10:58:03 ['452,', '241,', '214,', '660,', '210,', '528,', '118,', '544,', '898']
# Data written to CSV: 2024-04-29 10:58:04 ['452,', '240,', '213,', '660,', '210,', '528,', '117,', '544,', '898']
# Data written to CSV: 2024-04-29 10:58:05 ['452,', '240,', '213,', '660,', '210,', '528,', '117,', '544,', '898']
# Data written to CSV: 2024-04-29 10:58:06 ['451,', '240,', '212,', '660,', '209,', '528,', '117,', '544,', '897']
# Data written to CSV: 2024-04-29 10:58:07 ['450,', '238,', '211,', '659,', '208,', '527,', '115,', '543,', '897']
# Data written to CSV: 2024-04-29 10:58:08 ['451,', '239,', '211,', '659,', '208,', '527,', '116,', '543,', '897']
# Data written to CSV: 2024-04-29 10:58:09 ['450,', '237,', '210,', '658,', '207,', '526,', '114,', '544,', '897']
# Data written to CSV: 2024-04-29 10:58:10 ['450,', '238,', '211,', '659,', '207,', '526,', '115,', '542,', '897']
# Data written to CSV: 2024-04-29 10:58:11 ['450,', '238,', '210,', '659,', '208,', '526,', '115,', '543,', '897']
# Data written to CSV: 2024-04-29 10:58:12 ['449,', '236,', '208,', '658,', '206,', '525,', '113,', '543,', '897']
# Data written to CSV: 2024-04-29 10:58:13 ['449,', '236,', '208,', '658,', '206,', '526,', '113,', '543,', '897']
# Data written to CSV: 2024-04-29 10:58:14 ['449,', '236,', '208,', '658,', '206,', '525,', '113,', '543,', '897']
# Data written to CSV: 2024-04-29 10:58:15 ['449,', '236,', '208,', '658,', '206,', '525,', '113,', '542,', '897']
# Data written to CSV: 2024-04-29 10:58:16 ['449,', '236,', '208,', '658,', '206,', '525,', '113,', '542,', '897']
# Data written to CSV: 2024-04-29 10:58:17 ['449,', '236,', '208,', '658,', '206,', '525,', '113,', '542,', '897']
# Data written to CSV: 2024-04-29 10:58:18 ['449,', '237,', '208,', '658,', '206,', '526,', '113,', '542,', '897']
# Data written to CSV: 2024-04-29 10:58:19 ['449,', '236,', '208,', '658,', '206,', '525,', '113,', '541,', '897']
# Data written to CSV: 2024-04-29 10:58:20 ['448,', '236,', '208,', '657,', '206,', '525,', '113,', '542,', '897']
# Data written to CSV: 2024-04-29 10:58:21 ['448,', '237,', '208,', '657,', '206,', '525,', '113,', '541,', '897']
# Data written to CSV: 2024-04-29 10:58:22 ['448,', '236,', '207,', '657,', '206,', '525,', '113,', '541,', '896']
# Data written to CSV: 2024-04-29 10:58:23 ['448,', '236,', '207,', '657,', '206,', '525,', '113,', '541,', '897']
# Data written to CSV: 2024-04-29 10:58:24 ['448,', '236,', '207,', '657,', '206,', '525,', '113,', '540,', '897']
# Data written to CSV: 2024-04-29 10:58:25 ['448,', '236,', '207,', '657,', '206,', '525,', '113,', '541,', '896']
# Data written to CSV: 2024-04-29 10:58:26 ['447,', '236,', '207,', '657,', '205,', '525,', '113,', '541,', '896']
# Data written to CSV: 2024-04-29 10:58:27 ['447,', '236,', '206,', '657,', '205,', '525,', '112,', '540,', '896']
# Data written to CSV: 2024-04-29 10:58:28 ['447,', '236,', '206,', '657,', '206,', '525,', '113,', '540,', '897']
# Data written to CSV: 2024-04-29 10:58:29 ['447,', '235,', '206,', '656,', '205,', '524,', '112,', '540,', '896']
# Data written to CSV: 2024-04-29 10:58:30 ['447,', '236,', '205,', '656,', '205,', '524,', '112,', '540,', '896']
# Data written to CSV: 2024-04-29 10:58:31 ['446,', '235,', '205,', '656,', '204,', '524,', '112,', '539,', '896']
# Data written to CSV: 2024-04-29 10:58:32 ['447,', '236,', '206,', '656,', '205,', '525,', '113,', '539,', '896']
# Data written to CSV: 2024-04-29 10:58:33 ['446,', '235,', '205,', '656,', '204,', '524,', '112,', '539,', '896']
# Data written to CSV: 2024-04-29 10:58:34 ['446,', '235,', '205,', '656,', '204,', '524,', '112,', '538,', '896']
# Data written to CSV: 2024-04-29 10:58:35 ['447,', '236,', '206,', '656,', '205,', '525,', '112,', '538,', '896']
# Data written to CSV: 2024-04-29 10:58:36 ['447,', '236,', '206,', '656,', '205,', '525,', '112,', '538,', '896']
# Data written to CSV: 2024-04-29 10:58:37 ['446,', '235,', '204,', '655,', '204,', '524,', '112,', '538,', '896']
# Data written to CSV: 2024-04-29 10:58:38 ['445,', '235,', '204,', '655,', '204,', '524,', '111,', '538,', '896']
# Data written to CSV: 2024-04-29 10:58:39 ['445,', '235,', '204,', '655,', '204,', '524,', '111,', '537,', '896']
# Data written to CSV: 2024-04-29 10:58:40 ['445,', '235,', '204,', '655,', '204,', '524,', '111,', '538,', '896']
# Data written to CSV: 2024-04-29 10:58:41 ['445,', '235,', '204,', '655,', '204,', '524,', '111,', '538,', '896']
# Data written to CSV: 2024-04-29 10:58:42 ['445,', '235,', '203,', '655,', '203,', '523,', '111,', '538,', '896']
# Data written to CSV: 2024-04-29 10:58:43 ['445,', '235,', '203,', '654,', '203,', '523,', '111,', '537,', '896']
# Data written to CSV: 2024-04-29 10:58:44 ['445,', '234,', '203,', '655,', '204,', '523,', '111,', '537,', '896']
# Data written to CSV: 2024-04-29 10:58:45 ['444,', '234,', '203,', '654,', '203,', '523,', '111,', '537,', '896']
# Data written to CSV: 2024-04-29 10:58:46 ['444,', '234,', '203,', '654,', '203,', '523,', '111,', '537,', '895']
# Data written to CSV: 2024-04-29 10:58:47 ['444,', '234,', '203,', '654,', '203,', '523,', '111,', '537,', '896']
# Data written to CSV: 2024-04-29 10:58:48 ['444,', '234,', '203,', '654,', '203,', '523,', '111,', '536,', '895']
# Data written to CSV: 2024-04-29 10:58:49 ['444,', '234,', '202,', '654,', '203,', '523,', '111,', '536,', '896']
# Data written to CSV: 2024-04-29 10:58:50 ['444,', '234,', '203,', '654,', '203,', '523,', '111,', '536,', '895']
# Data written to CSV: 2024-04-29 10:58:51 ['444,', '234,', '203,', '654,', '203,', '523,', '111,', '536,', '895']
# Data written to CSV: 2024-04-29 10:58:52 ['444,', '235,', '202,', '654,', '203,', '523,', '111,', '536,', '896']
# Data written to CSV: 2024-04-29 10:58:53 ['444,', '235,', '202,', '654,', '203,', '523,', '111,', '536,', '895']
# Data written to CSV: 2024-04-29 10:58:54 ['444,', '234,', '202,', '654,', '203,', '523,', '111,', '535,', '896']
# Data written to CSV: 2024-04-29 10:58:55 ['443,', '234,', '202,', '654,', '203,', '523,', '111,', '535,', '895']
# Data written to CSV: 2024-04-29 10:58:56 ['443,', '234,', '202,', '653,', '203,', '523,', '110,', '535,', '895']
# Data written to CSV: 2024-04-29 10:58:57 ['443,', '234,', '202,', '653,', '203,', '522,', '110,', '535,', '895']
# Data written to CSV: 2024-04-29 10:58:58 ['443,', '234,', '202,', '653,', '203,', '522,', '110,', '534,', '895']
# Data written to CSV: 2024-04-29 10:58:59 ['443,', '234,', '202,', '653,', '203,', '522,', '111,', '535,', '895']
# Data written to CSV: 2024-04-29 10:59:00 ['443,', '234,', '201,', '653,', '203,', '522,', '110,', '535,', '895']
# Data written to CSV: 2024-04-29 10:59:01 ['443,', '234,', '201,', '653,', '203,', '522,', '110,', '534,', '895']
# Data written to CSV: 2024-04-29 10:59:02 ['442,', '234,', '201,', '653,', '203,', '522,', '110,', '534,', '895']
# Data written to CSV: 2024-04-29 10:59:03 ['442,', '234,', '201,', '653,', '203,', '522,', '110,', '534,', '895']
# Data written to CSV: 2024-04-29 10:59:04 ['443,', '235,', '202,', '653,', '203,', '522,', '112,', '534,', '895']
# Data written to CSV: 2024-04-29 10:59:05 ['443,', '234,', '201,', '653,', '203,', '522,', '111,', '534,', '895']
# Data written to CSV: 2024-04-29 10:59:06 ['442,', '234,', '201,', '653,', '203,', '522,', '111,', '534,', '895']
# Data written to CSV: 2024-04-29 10:59:07 ['442,', '234,', '200,', '652,', '202,', '522,', '110,', '532,', '895']
# Data written to CSV: 2024-04-29 10:59:08 ['442,', '234,', '200,', '652,', '202,', '521,', '110,', '533,', '895']
# Data written to CSV: 2024-04-29 10:59:09 ['442,', '234,', '201,', '652,', '203,', '522,', '111,', '533,', '895']
# Data written to CSV: 2024-04-29 10:59:10 ['441,', '233,', '200,', '652,', '202,', '521,', '110,', '533,', '895']
# Data written to CSV: 2024-04-29 10:59:11 ['442,', '234,', '200,', '652,', '202,', '521,', '110,', '532,', '895']
# Data written to CSV: 2024-04-29 10:59:12 ['442,', '234,', '200,', '652,', '203,', '522,', '111,', '532,', '895']
# Data written to CSV: 2024-04-29 10:59:13 ['441,', '234,', '200,', '651,', '202,', '521,', '110,', '532,', '895']
# Data written to CSV: 2024-04-29 10:59:14 ['440,', '233,', '199,', '651,', '201,', '521,', '109,', '531,', '895']
# Data written to CSV: 2024-04-29 10:59:15 ['440,', '233,', '198,', '651,', '201,', '520,', '109,', '532,', '895']
# Data written to CSV: 2024-04-29 10:59:16 ['440,', '232,', '198,', '651,', '201,', '520,', '109,', '532,', '895']
# Data written to CSV: 2024-04-29 10:59:17 ['440,', '232,', '198,', '651,', '201,', '520,', '108,', '530,', '895']
# Data written to CSV: 2024-04-29 10:59:18 ['440,', '232,', '198,', '651,', '201,', '520,', '109,', '532,', '895']
# Data written to CSV: 2024-04-29 10:59:19 ['439,', '232,', '198,', '651,', '201,', '520,', '108,', '532,', '895']
# Data written to CSV: 2024-04-29 10:59:20 ['439,', '232,', '197,', '650,', '200,', '520,', '108,', '530,', '895']
# Data written to CSV: 2024-04-29 10:59:21 ['439,', '232,', '197,', '650,', '200,', '520,', '108,', '531,', '895']
# Data written to CSV: 2024-04-29 10:59:22 ['439,', '232,', '197,', '650,', '200,', '520,', '108,', '531,', '895']
# Data written to CSV: 2024-04-29 10:59:24 ['439,', '232,', '197,', '650,', '200,', '520,', '108,', '531,', '895']
# Data written to CSV: 2024-04-29 10:59:25 ['439,', '232,', '197,', '650,', '200,', '520,', '108,', '531,', '895']
# Data written to CSV: 2024-04-29 10:59:26 ['439,', '232,', '197,', '650,', '200,', '520,', '108,', '530,', '895']
# Data written to CSV: 2024-04-29 10:59:27 ['439,', '232,', '197,', '650,', '200,', '520,', '108,', '530,', '895']
# Data written to CSV: 2024-04-29 10:59:28 ['439,', '232,', '197,', '650,', '200,', '519,', '108,', '529,', '895']
# Data written to CSV: 2024-04-29 10:59:29 ['438,', '232,', '197,', '650,', '200,', '519,', '108,', '530,', '895']
# Data written to CSV: 2024-04-29 10:59:30 ['438,', '232,', '196,', '650,', '200,', '519,', '108,', '530,', '895']
# Data written to CSV: 2024-04-29 10:59:31 ['438,', '232,', '196,', '649,', '200,', '519,', '108,', '530,', '894']
# Data written to CSV: 2024-04-29 10:59:32 ['438,', '231,', '196,', '649,', '200,', '519,', '108,', '529,', '895']
# Data written to CSV: 2024-04-29 10:59:33 ['438,', '231,', '196,', '649,', '200,', '519,', '108,', '529,', '895']
# Data written to CSV: 2024-04-29 10:59:34 ['438,', '231,', '196,', '649,', '200,', '519,', '108,', '529,', '895']
# Data written to CSV: 2024-04-29 10:59:35 ['438,', '231,', '196,', '649,', '200,', '519,', '108,', '529,', '894']
# Data written to CSV: 2024-04-29 10:59:36 ['438,', '231,', '195,', '649,', '199,', '519,', '108,', '529,', '895']
# Data written to CSV: 2024-04-29 10:59:37 ['437,', '231,', '195,', '649,', '199,', '519,', '108,', '528,', '895']
# Data written to CSV: 2024-04-29 10:59:38 ['437,', '231,', '195,', '649,', '199,', '518,', '107,', '528,', '894']
# Data written to CSV: 2024-04-29 10:59:39 ['437,', '231,', '195,', '648,', '199,', '518,', '107,', '528,', '894']
# Data written to CSV: 2024-04-29 10:59:40 ['437,', '231,', '195,', '648,', '199,', '518,', '107,', '528,', '894']
# Data written to CSV: 2024-04-29 10:59:41 ['437,', '231,', '194,', '648,', '199,', '518,', '107,', '528,', '894']
# Data written to CSV: 2024-04-29 10:59:42 ['437,', '230,', '194,', '648,', '198,', '518,', '107,', '528,', '894']
# Data written to CSV: 2024-04-29 10:59:43 ['436,', '230,', '194,', '648,', '198,', '518,', '107,', '528,', '894']
# Data written to CSV: 2024-04-29 10:59:44 ['436,', '230,', '194,', '648,', '198,', '518,', '107,', '528,', '894']
# Data written to CSV: 2024-04-29 10:59:45 ['436,', '230,', '194,', '648,', '198,', '518,', '107,', '528,', '894']
# Data written to CSV: 2024-04-29 10:59:46 ['436,', '230,', '194,', '648,', '198,', '518,', '107,', '527,', '894']
# Data written to CSV: 2024-04-29 10:59:47 ['436,', '230,', '193,', '648,', '198,', '518,', '107,', '527,', '894']
# Data written to CSV: 2024-04-29 10:59:48 ['436,', '230,', '193,', '647,', '198,', '518,', '106,', '527,', '894']
# Data written to CSV: 2024-04-29 10:59:49 ['436,', '230,', '193,', '647,', '198,', '517,', '107,', '527,', '894']
# Data written to CSV: 2024-04-29 10:59:50 ['436,', '230,', '193,', '647,', '198,', '517,', '107,', '526,', '894']
# Data written to CSV: 2024-04-29 10:59:51 ['436,', '230,', '193,', '647,', '198,', '517,', '107,', '527,', '894']
# Data written to CSV: 2024-04-29 10:59:52 ['435,', '230,', '193,', '647,', '198,', '517,', '107,', '526,', '894']
# Data written to CSV: 2024-04-29 10:59:53 ['435,', '230,', '193,', '647,', '198,', '517,', '107,', '526,', '894']
# Data written to CSV: 2024-04-29 10:59:54 ['435,', '230,', '193,', '647,', '198,', '517,', '107,', '526,', '894']
# Data written to CSV: 2024-04-29 10:59:55 ['435,', '230,', '193,', '647,', '198,', '517,', '107,', '526,', '894']
# Data written to CSV: 2024-04-29 10:59:56 ['435,', '230,', '193,', '647,', '198,', '517,', '107,', '526,', '894']
# Data written to CSV: 2024-04-29 10:59:57 ['435,', '230,', '193,', '646,', '198,', '517,', '107,', '525,', '894']
# Data written to CSV: 2024-04-29 10:59:58 ['435,', '230,', '193,', '646,', '198,', '517,', '107,', '525,', '894']
# Data written to CSV: 2024-04-29 10:59:59 ['435,', '230,', '193,', '646,', '198,', '517,', '107,', '525,', '894']
# Data written to CSV: 2024-04-29 11:00:00 ['435,', '230,', '192,', '646,', '198,', '517,', '107,', '525,', '894']
# Data written to CSV: 2024-04-29 11:00:01 ['434,', '230,', '192,', '646,', '198,', '517,', '106,', '524,', '894']
# Data written to CSV: 2024-04-29 11:00:02 ['434,', '230,', '192,', '646,', '197,', '516,', '107,', '525,', '894']
# Data written to CSV: 2024-04-29 11:00:03 ['434,', '230,', '192,', '646,', '198,', '516,', '107,', '525,', '894']
# Data written to CSV: 2024-04-29 11:00:04 ['434,', '230,', '192,', '645,', '197,', '516,', '106,', '523,', '894']
# Data written to CSV: 2024-04-29 11:00:05 ['434,', '229,', '192,', '646,', '197,', '516,', '106,', '524,', '894']
# Data written to CSV: 2024-04-29 11:00:06 ['434,', '229,', '192,', '646,', '197,', '516,', '106,', '524,', '894']
# Data written to CSV: 2024-04-29 11:00:07 ['434,', '230,', '192,', '645,', '197,', '516,', '107,', '524,', '894']
# Data written to CSV: 2024-04-29 11:00:08 ['434,', '230,', '191,', '645,', '197,', '516,', '106,', '524,', '894']
# Data written to CSV: 2024-04-29 11:00:09 ['433,', '230,', '191,', '645,', '197,', '516,', '106,', '523,', '894']
# Data written to CSV: 2024-04-29 11:00:10 ['433,', '229,', '191,', '645,', '197,', '516,', '106,', '523,', '894']
# Data written to CSV: 2024-04-29 11:00:11 ['433,', '229,', '191,', '645,', '197,', '516,', '106,', '523,', '894']
# Data written to CSV: 2024-04-29 11:00:12 ['433,', '230,', '191,', '645,', '197,', '516,', '106,', '523,', '894']
# Data written to CSV: 2024-04-29 11:00:13 ['433,', '229,', '191,', '645,', '197,', '516,', '106,', '522,', '894']
# Data written to CSV: 2024-04-29 11:00:14 ['433,', '229,', '191,', '645,', '197,', '515,', '106,', '523,', '894']
# Data written to CSV: 2024-04-29 11:00:15 ['433,', '229,', '191,', '645,', '197,', '515,', '106,', '523,', '894']
# Data written to CSV: 2024-04-29 11:00:16 ['433,', '229,', '191,', '644,', '197,', '515,', '106,', '522,', '894']
# Data written to CSV: 2024-04-29 11:00:17 ['432,', '229,', '191,', '644,', '197,', '515,', '106,', '522,', '894']
# Data written to CSV: 2024-04-29 11:00:18 ['432,', '229,', '190,', '644,', '197,', '515,', '106,', '522,', '894']
# Data written to CSV: 2024-04-29 11:00:19 ['432,', '229,', '190,', '644,', '197,', '515,', '106,', '522,', '894']
# Data written to CSV: 2024-04-29 11:00:20 ['432,', '229,', '190,', '644,', '196,', '515,', '106,', '522,', '893']
# Data written to CSV: 2024-04-29 11:00:21 ['432,', '229,', '190,', '644,', '196,', '514,', '106,', '521,', '893']
# Data written to CSV: 2024-04-29 11:00:22 ['432,', '229,', '190,', '644,', '196,', '515,', '106,', '522,', '893']
# Data written to CSV: 2024-04-29 11:00:23 ['432,', '229,', '190,', '644,', '196,', '514,', '106,', '521,', '894']
# Data written to CSV: 2024-04-29 11:00:24 ['432,', '229,', '190,', '643,', '196,', '514,', '106,', '520,', '893']
# Data written to CSV: 2024-04-29 11:00:25 ['431,', '229,', '189,', '643,', '196,', '514,', '106,', '520,', '893']
# Data written to CSV: 2024-04-29 11:00:26 ['431,', '229,', '189,', '643,', '196,', '514,', '106,', '521,', '893']
# Data written to CSV: 2024-04-29 11:00:27 ['431,', '228,', '189,', '643,', '196,', '514,', '105,', '520,', '893']
# Data written to CSV: 2024-04-29 11:00:28 ['431,', '228,', '189,', '643,', '196,', '514,', '105,', '520,', '893']
# Data written to CSV: 2024-04-29 11:00:29 ['431,', '228,', '188,', '643,', '196,', '514,', '105,', '520,', '893']
# Data written to CSV: 2024-04-29 11:00:30 ['431,', '228,', '189,', '643,', '196,', '514,', '105,', '520,', '893']
# Data written to CSV: 2024-04-29 11:00:31 ['430,', '228,', '188,', '643,', '195,', '513,', '105,', '520,', '893']
# Data written to CSV: 2024-04-29 11:00:32 ['430,', '228,', '188,', '643,', '195,', '514,', '105,', '520,', '893']
# Data written to CSV: 2024-04-29 11:00:33 ['430,', '228,', '188,', '642,', '195,', '513,', '105,', '520,', '893']
# Data written to CSV: 2024-04-29 11:00:34 ['430,', '228,', '188,', '642,', '196,', '513,', '105,', '519,', '893']
# Data written to CSV: 2024-04-29 11:00:35 ['430,', '228,', '188,', '642,', '195,', '513,', '105,', '520,', '893']
# Data written to CSV: 2024-04-29 11:00:36 ['430,', '228,', '188,', '642,', '195,', '513,', '105,', '519,', '893']
# Data written to CSV: 2024-04-29 11:00:37 ['430,', '228,', '188,', '642,', '195,', '513,', '105,', '520,', '893']
# Data written to CSV: 2024-04-29 11:00:38 ['430,', '228,', '188,', '642,', '195,', '513,', '105,', '520,', '893']
# Data written to CSV: 2024-04-29 11:00:39 ['430,', '228,', '188,', '642,', '195,', '513,', '105,', '519,', '893']
# Data written to CSV: 2024-04-29 11:00:40 ['430,', '227,', '187,', '642,', '195,', '513,', '105,', '519,', '893']
# Data written to CSV: 2024-04-29 11:00:41 ['430,', '228,', '187,', '642,', '195,', '513,', '105,', '519,', '893']
# Data written to CSV: 2024-04-29 11:00:42 ['429,', '228,', '187,', '642,', '195,', '513,', '105,', '518,', '893']
# Data written to CSV: 2024-04-29 11:00:43 ['430,', '228,', '187,', '641,', '195,', '513,', '105,', '519,', '893']
# Data written to CSV: 2024-04-29 11:00:44 ['429,', '228,', '187,', '641,', '195,', '513,', '105,', '518,', '893']
# Data written to CSV: 2024-04-29 11:00:46 ['429,', '227,', '187,', '641,', '195,', '513,', '105,', '518,', '893']
# Data written to CSV: 2024-04-29 11:00:47 ['429,', '227,', '187,', '641,', '195,', '513,', '105,', '518,', '893']
# Data written to CSV: 2024-04-29 11:00:48 ['429,', '228,', '187,', '641,', '195,', '513,', '105,', '518,', '893']
# Data written to CSV: 2024-04-29 11:00:49 ['429,', '227,', '187,', '641,', '195,', '513,', '105,', '518,', '893']
# Data written to CSV: 2024-04-29 11:00:50 ['429,', '227,', '187,', '641,', '195,', '512,', '105,', '518,', '893']
# Data written to CSV: 2024-04-29 11:00:51 ['429,', '227,', '187,', '641,', '195,', '512,', '105,', '518,', '893']
# Data written to CSV: 2024-04-29 11:00:52 ['429,', '227,', '186,', '641,', '195,', '512,', '105,', '518,', '893']
# Data written to CSV: 2024-04-29 11:00:53 ['429,', '227,', '186,', '641,', '195,', '512,', '105,', '516,', '893']
# Data written to CSV: 2024-04-29 11:00:54 ['428,', '227,', '186,', '641,', '195,', '512,', '105,', '518,', '893']
# Data written to CSV: 2024-04-29 11:00:55 ['428,', '227,', '186,', '641,', '195,', '512,', '105,', '517,', '893']
# Data written to CSV: 2024-04-29 11:00:56 ['428,', '227,', '186,', '640,', '195,', '512,', '105,', '517,', '892']
# Data written to CSV: 2024-04-29 11:00:57 ['428,', '227,', '186,', '640,', '194,', '512,', '105,', '516,', '893']
# Data written to CSV: 2024-04-29 11:00:58 ['428,', '227,', '186,', '641,', '195,', '512,', '105,', '517,', '893']
# Data written to CSV: 2024-04-29 11:00:59 ['428,', '227,', '186,', '640,', '195,', '512,', '105,', '516,', '893']
# Data written to CSV: 2024-04-29 11:01:00 ['428,', '227,', '186,', '640,', '195,', '512,', '105,', '516,', '893']
# Data written to CSV: 2024-04-29 11:01:01 ['428,', '227,', '186,', '640,', '195,', '512,', '105,', '516,', '893']
# Data written to CSV: 2024-04-29 11:01:02 ['428,', '227,', '186,', '640,', '194,', '511,', '105,', '516,', '893']
# Data written to CSV: 2024-04-29 11:01:03 ['428,', '227,', '185,', '640,', '194,', '511,', '105,', '516,', '892']
# Data written to CSV: 2024-04-29 11:01:04 ['428,', '227,', '185,', '640,', '194,', '511,', '105,', '515,', '893']
# Data written to CSV: 2024-04-29 11:01:05 ['427,', '227,', '186,', '640,', '194,', '511,', '105,', '515,', '893']
# Data written to CSV: 2024-04-29 11:01:06 ['427,', '227,', '185,', '640,', '194,', '511,', '105,', '515,', '893']
# Data written to CSV: 2024-04-29 11:01:07 ['427,', '227,', '185,', '640,', '194,', '511,', '105,', '515,', '893']
# Data written to CSV: 2024-04-29 11:01:08 ['427,', '226,', '185,', '640,', '194,', '511,', '104,', '515,', '892']
# Data written to CSV: 2024-04-29 11:01:09 ['427,', '227,', '185,', '639,', '194,', '511,', '105,', '515,', '892']
# Data written to CSV: 2024-04-29 11:01:10 ['427,', '227,', '185,', '639,', '194,', '511,', '105,', '515,', '892']
# Data written to CSV: 2024-04-29 11:01:11 ['427,', '227,', '185,', '639,', '194,', '511,', '105,', '515,', '892']
# Data written to CSV: 2024-04-29 11:01:12 ['427,', '227,', '185,', '639,', '194,', '510,', '105,', '515,', '892']
# Data written to CSV: 2024-04-29 11:01:13 ['427,', '227,', '185,', '639,', '194,', '510,', '105,', '515,', '892']
# Data written to CSV: 2024-04-29 11:01:14 ['426,', '227,', '184,', '639,', '194,', '510,', '105,', '515,', '893']
# Data written to CSV: 2024-04-29 11:01:15 ['427,', '226,', '184,', '639,', '194,', '510,', '105,', '515,', '892']
# Data written to CSV: 2024-04-29 11:01:16 ['426,', '227,', '184,', '639,', '194,', '510,', '105,', '514,', '892']
# Data written to CSV: 2024-04-29 11:01:17 ['426,', '226,', '184,', '639,', '194,', '510,', '104,', '515,', '892']
# Data written to CSV: 2024-04-29 11:01:18 ['426,', '227,', '184,', '639,', '194,', '510,', '104,', '515,', '892']
# Data written to CSV: 2024-04-29 11:01:19 ['426,', '226,', '184,', '638,', '194,', '510,', '105,', '515,', '892']
# Data written to CSV: 2024-04-29 11:01:20 ['426,', '227,', '184,', '638,', '194,', '510,', '104,', '514,', '892']
# Data written to CSV: 2024-04-29 11:01:21 ['426,', '226,', '184,', '638,', '194,', '510,', '105,', '515,', '892']
# Data written to CSV: 2024-04-29 11:01:22 ['426,', '226,', '184,', '638,', '194,', '510,', '105,', '515,', '892']
# Data written to CSV: 2024-04-29 11:01:23 ['426,', '226,', '184,', '638,', '194,', '510,', '105,', '514,', '892']
# Data written to CSV: 2024-04-29 11:01:24 ['426,', '226,', '184,', '638,', '194,', '510,', '104,', '514,', '892']
# Data written to CSV: 2024-04-29 11:01:25 ['426,', '226,', '183,', '638,', '194,', '510,', '105,', '514,', '892']
# Data written to CSV: 2024-04-29 11:01:26 ['426,', '226,', '183,', '638,', '194,', '510,', '105,', '514,', '892']
# Data written to CSV: 2024-04-29 11:01:27 ['426,', '226,', '183,', '638,', '194,', '510,', '105,', '514,', '892']
# Data written to CSV: 2024-04-29 11:01:28 ['426,', '227,', '183,', '638,', '194,', '510,', '104,', '513,', '892']
# Data written to CSV: 2024-04-29 11:01:29 ['426,', '226,', '183,', '638,', '194,', '510,', '105,', '514,', '892']
# Data written to CSV: 2024-04-29 11:01:30 ['426,', '226,', '183,', '638,', '194,', '510,', '105,', '514,', '892']
# Data written to CSV: 2024-04-29 11:01:31 ['425,', '226,', '183,', '638,', '194,', '510,', '104,', '514,', '892']
# Data written to CSV: 2024-04-29 11:01:32 ['425,', '226,', '183,', '638,', '194,', '510,', '105,', '513,', '892']
# Data written to CSV: 2024-04-29 11:01:33 ['425,', '226,', '183,', '637,', '194,', '509,', '105,', '513,', '892']
# Data written to CSV: 2024-04-29 11:01:34 ['425,', '226,', '183,', '638,', '194,', '509,', '104,', '513,', '892']
# Data written to CSV: 2024-04-29 11:01:35 ['425,', '226,', '183,', '637,', '194,', '509,', '105,', '513,', '892']
# Data written to CSV: 2024-04-29 11:01:36 ['425,', '226,', '183,', '637,', '193,', '509,', '104,', '512,', '892']
# Data written to CSV: 2024-04-29 11:01:37 ['425,', '226,', '183,', '637,', '194,', '509,', '104,', '513,', '892']
# Data written to CSV: 2024-04-29 11:01:38 ['425,', '226,', '183,', '637,', '193,', '509,', '105,', '513,', '892']
# Data written to CSV: 2024-04-29 11:01:39 ['425,', '226,', '183,', '637,', '193,', '509,', '105,', '512,', '892']
# Data written to CSV: 2024-04-29 11:01:40 ['425,', '226,', '182,', '637,', '194,', '509,', '104,', '512,', '892']
# Data written to CSV: 2024-04-29 11:01:41 ['425,', '226,', '182,', '637,', '194,', '509,', '105,', '512,', '892']
# Data written to CSV: 2024-04-29 11:01:42 ['424,', '226,', '182,', '637,', '193,', '509,', '104,', '512,', '892']
# Data written to CSV: 2024-04-29 11:01:43 ['424,', '226,', '182,', '637,', '193,', '509,', '104,', '511,', '892']
# ...
# Data written to CSV: 2024-04-29 16:08:13 ['339,', '132,', '109,', '489,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:14 ['339,', '132,', '109,', '489,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:15 ['338,', '132,', '109,', '489,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:16 ['338,', '132,', '109,', '489,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:17 ['339,', '132,', '109,', '488,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:18 ['338,', '132,', '109,', '489,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:19 ['338,', '132,', '109,', '488,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:20 ['338,', '132,', '109,', '488,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:21 ['338,', '132,', '109,', '488,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:22 ['338,', '132,', '109,', '488,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:23 ['338,', '132,', '109,', '489,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:24 ['338,', '132,', '109,', '489,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:25 ['338,', '132,', '109,', '488,', '146,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:08:26 ['338,', '132,', '109,', '488,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:27 ['338,', '131,', '108,', '488,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:08:28 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:29 ['338,', '131,', '109,', '488,', '145,', '382,', '86,', '324,', '804']
# Data written to CSV: 2024-04-29 16:08:30 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:31 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:32 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:33 ['338,', '132,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:34 ['338,', '131,', '109,', '488,', '145,', '382,', '86,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:35 ['337,', '131,', '108,', '488,', '145,', '381,', '86,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:36 ['338,', '131,', '108,', '488,', '145,', '382,', '86,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:37 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:38 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:39 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:40 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:41 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:42 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:43 ['338,', '132,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:44 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:45 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:46 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:47 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:48 ['338,', '131,', '108,', '488,', '145,', '382,', '86,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:49 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:50 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:51 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:53 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:54 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:55 ['338,', '131,', '109,', '488,', '146,', '382,', '87,', '325,', '805']
# Data written to CSV: 2024-04-29 16:08:56 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:57 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:58 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:08:59 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:00 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:01 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:02 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:03 ['339,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:04 ['339,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:05 ['339,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:06 ['339,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:07 ['339,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:08 ['339,', '131,', '109,', '488,', '146,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:09 ['339,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:10 ['339,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:11 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:12 ['338,', '132,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:13 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:14 ['338,', '132,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:15 ['338,', '132,', '109,', '488,', '145,', '382,', '87,', '325,', '805']
# Data written to CSV: 2024-04-29 16:09:16 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:17 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '325,', '805']
# Data written to CSV: 2024-04-29 16:09:18 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '804']
# Data written to CSV: 2024-04-29 16:09:19 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:20 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:21 ['338,', '132,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:22 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:23 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:24 ['338,', '131,', '109,', '488,', '146,', '381,', '86,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:25 ['339,', '131,', '109,', '488,', '145,', '381,', '86,', '323,', '805']
# Data written to CSV: 2024-04-29 16:09:26 ['339,', '131,', '109,', '488,', '145,', '381,', '86,', '323,', '805']
# Data written to CSV: 2024-04-29 16:09:27 ['339,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:28 ['339,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:29 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:30 ['338,', '131,', '108,', '488,', '145,', '381,', '86,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:31 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:32 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:33 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:34 ['338,', '131,', '109,', '488,', '145,', '381,', '86,', '324,', '804']
# Data written to CSV: 2024-04-29 16:09:35 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '325,', '805']
# Data written to CSV: 2024-04-29 16:09:36 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:37 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:38 ['338,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:39 ['338,', '131,', '109,', '488,', '145,', '382,', '86,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:40 ['338,', '131,', '109,', '488,', '145,', '381,', '86,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:41 ['338,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '804']
# Data written to CSV: 2024-04-29 16:09:42 ['339,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:43 ['338,', '131,', '109,', '488,', '145,', '382,', '86,', '325,', '805']
# Data written to CSV: 2024-04-29 16:09:44 ['339,', '131,', '109,', '488,', '145,', '381,', '87,', '324,', '804']
# Data written to CSV: 2024-04-29 16:09:45 ['339,', '131,', '109,', '488,', '145,', '382,', '86,', '324,', '804']
# Data written to CSV: 2024-04-29 16:09:46 ['339,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:47 ['339,', '131,', '109,', '488,', '145,', '381,', '86,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:48 ['339,', '131,', '109,', '488,', '145,', '381,', '86,', '324,', '804']
# Data written to CSV: 2024-04-29 16:09:49 ['339,', '131,', '109,', '489,', '145,', '382,', '86,', '324,', '804']
# Data written to CSV: 2024-04-29 16:09:50 ['339,', '131,', '109,', '489,', '145,', '382,', '87,', '325,', '805']
# Data written to CSV: 2024-04-29 16:09:51 ['339,', '131,', '109,', '488,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:52 ['339,', '131,', '109,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:09:53 ['339,', '131,', '109,', '489,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:54 ['339,', '131,', '109,', '489,', '145,', '382,', '87,', '324,', '804']
# Data written to CSV: 2024-04-29 16:09:55 ['339,', '131,', '109,', '489,', '145,', '382,', '86,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:56 ['339,', '131,', '109,', '489,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:09:57 ['340,', '131,', '109,', '489,', '145,', '382,', '87,', '324,', '804']
# Data written to CSV: 2024-04-29 16:09:58 ['340,', '131,', '109,', '489,', '145,', '382,', '87,', '324,', '804']
# Data written to CSV: 2024-04-29 16:09:59 ['340,', '131,', '109,', '489,', '145,', '382,', '86,', '324,', '805']
# Data written to CSV: 2024-04-29 16:10:00 ['340,', '131,', '109,', '489,', '145,', '382,', '87,', '324,', '804']
# Data written to CSV: 2024-04-29 16:10:01 ['341,', '132,', '109,', '489,', '145,', '382,', '87,', '324,', '804']
# Data written to CSV: 2024-04-29 16:10:02 ['341,', '131,', '109,', '489,', '145,', '382,', '86,', '324,', '805']
# Data written to CSV: 2024-04-29 16:10:03 ['341,', '131,', '109,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:04 ['341,', '131,', '110,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:05 ['340,', '132,', '109,', '489,', '145,', '382,', '87,', '323,', '804']
# Data written to CSV: 2024-04-29 16:10:06 ['340,', '131,', '109,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:07 ['340,', '132,', '109,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:08 ['340,', '131,', '109,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:09 ['340,', '131,', '109,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:10 ['340,', '131,', '109,', '489,', '145,', '382,', '86,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:11 ['340,', '131,', '109,', '488,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:12 ['341,', '132,', '109,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:13 ['341,', '132,', '109,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:14 ['341,', '132,', '110,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:16 ['341,', '132,', '110,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:17 ['341,', '132,', '110,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:18 ['342,', '132,', '110,', '489,', '146,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:19 ['342,', '132,', '110,', '489,', '146,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:20 ['342,', '132,', '110,', '489,', '146,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:21 ['342,', '132,', '110,', '489,', '146,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:22 ['342,', '132,', '110,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:23 ['343,', '132,', '110,', '489,', '145,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:24 ['343,', '132,', '110,', '489,', '146,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:25 ['343,', '132,', '110,', '489,', '146,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:26 ['343,', '132,', '110,', '489,', '146,', '382,', '87,', '323,', '805']
# Data written to CSV: 2024-04-29 16:10:27 ['343,', '132,', '110,', '489,', '145,', '382,', '87,', '324,', '805']
# Data written to CSV: 2024-04-29 16:10:28 ['343,', '132,', '110,', '490,', '146,', '382,', '87,', '324,', '805']
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-2-cebc81def531> in <module>
#      36                             })
# ---> 37             csvfile.flush()  # Ensure data is written immediately
#      38
#
# PermissionError: [Errno 13] Permission denied
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# PermissionError: [Errno 13] Permission denied
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-2-cebc81def531> in <module>
#      42     except KeyboardInterrupt:
#      43         print("Exiting...")
# ---> 44         ser.close()  # Close serial connection when exiting
#
# PermissionError: [Errno 13] Permission denied

# %%
# import serial
# import csv
# import time

# # Establish serial connection
# ser = serial.Serial('COM8', 115200)  

# # Open CSV file for writing
# with open('sensor_data.csv', 'w', newline='', encoding='utf-8') as csvfile:
#     fieldnames = ['Timestamp', 'mq3', 'mq2', 'mq6', 'mq9', 'mq8', 'mq5', 'mics_Vnox', 'mics_Vred']
#     writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
#     writer.writeheader()

#     # Read and write data indefinitely
#     try:
#         while True:
#             # Read data from serial port
#             line = ser.readline().decode('utf-8').strip()
#             print("Received line:", line)  # Add this line for debugging
#             sensor_data = line.split()
#             print("Split data:", sensor_data)  # Add this line for debugging

#             # Get current timestamp
#             timestamp = time.strftime('%Y-%m-%d %H:%M:%S')

#             # Write data to CSV file
#             writer.writerow({'Timestamp': timestamp,
#                              'mq3': sensor_data[0].replace(',', ''),   # Use correct keys
#                              'mq2': sensor_data[1].replace(',', ''),  
#                              'mq6': sensor_data[2].replace(',', ''),
#                              'mq9': sensor_data[3].replace(',', ''),
#                              'mq8': sensor_data[4].replace(',', ''),
#                              'mq5': sensor_data[5].replace(',', ''),
#                              'mics_Vnox': sensor_data[6].replace(',', ''),
#                              'mics_Vred': sensor_data[7]
#                             })
#             csvfile.flush()  # Ensure data is written immediately

#             # Print data to console
#             print("Data written to CSV:", timestamp, sensor_data)

#     except KeyboardInterrupt:
#         print("Exiting...")
#         ser.close()  # Close serial connection when exiting
